# %% [markdown]
# <a href="https://colab.research.google.com/github/Mozun1/data-analysis/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
import pandas as pd

# %%
data = pd.read_excel("https://www.stats.gov.sa/documents/20117/2435259/ntyj_ltjr_ldkhly_lrb_lwl_2019.xlsx/3f7174bb-16e5-1c61-547a-0bfb12ed66e2?t=1734050601389")

# %%
data.head()
# Out:
#   Unnamed: 0                                         Unnamed: 1
# 0        NaN                                                NaN
# 1        NaN                    مسح التجاره الداخليه الربع ا...
# 2        NaN                                                NaN
# 3  المحتويات                                                NaN
# 4        NaN                                                NaN

# %%
data.tail()
# Out:
#    Unnamed: 0               Unnamed: 1
# 17         13  أدنى متطلب لغير السعودي
# 18         14        الموقع الإلكتروني
# 19         15                موقع وسيط
# 20         16   تقييم الخدمات الحكومية
# 21         17          هل حصلت على قرض

# %%
print (data.isnull().sum())
# Out:
# Unnamed: 0    4
# Unnamed: 1    4
# dtype: int64

# %%
data.isnull().sum(axis=0)
# Out:
# Unnamed: 0    4
# Unnamed: 1    4
# dtype: int64

# %%
data.shape
# Out:
# (22, 2)

# %%
(data.isnull().sum(axis = 0) / data.shape[0]) * 100
# Out:
# Unnamed: 0    18.181818
# Unnamed: 1    18.181818
# dtype: float64

# %%
data.dropna()
# Out:
#    Unnamed: 0                     Unnamed: 1
# 5           1                        المنشآت
# 6           2  المشتغلين حسب الجنس والجنسية
# 7           3          المشتغلين حسب المناطق
# 8           4   المشتغلين حسب الفئات العمرية
# 9           5                متوسط التعويضات
# 10          6             النفقات والإيرادات
# 11          7                   فائض التشغيل
# 12          8                 معدل الانتاجية
# 13          9           المبيعات الإلكترونية
# 14         10                  دفاتر محاسبية
# 15         11                  انظمة محاسبية
# 16         12             أدنى متطلب للسعودي
# 17         13        أدنى متطلب لغير السعودي
# 18         14              الموقع الإلكتروني
# 19         15                      موقع وسيط
# 20         16         تقييم الخدمات الحكومية
# 21         17                هل حصلت على قرض

# %%
data
# Out:
#    Unnamed: 0                                         Unnamed: 1
# 0         NaN                                                NaN
# 1         NaN                    مسح التجاره الداخليه الربع ا...
# 2         NaN                                                NaN
# 3   المحتويات                                                NaN
# 4         NaN                                                NaN
# 5           1                                            المنشآت
# 6           2                      المشتغلين حسب الجنس والجنسية
# 7           3                              المشتغلين حسب المناطق
# 8           4                       المشتغلين حسب الفئات العمرية
# 9           5                                    متوسط التعويضات
# 10          6                                 النفقات والإيرادات
# 11          7                                       فائض التشغيل
# 12          8                                     معدل الانتاجية
# ...
